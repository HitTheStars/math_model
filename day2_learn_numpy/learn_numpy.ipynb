# %%
import numpy as np

# %%
popu=np.array([19571216,
19673200,
19854526,
20104710,
19463131,
19544098,
19593849,
19636391,
19657321,
19653431,
19626488])

# %%
print(popu[0],popu[-1])
# Out:
# 19571216 19626488

# %%
change=np.array([])
for i in range(popu.shape[0]):
    if i<popu.shape[0]-1 :
        change=np.append(change,popu[i+1]-popu[i])
print(change)
# Out:
# [ 101984.  181326.  250184. -641579.   80967.   49751.   42542.   20930.
#    -3890.  -26943.]

# %%
change=np.array([])
for i in range(popu.shape[0]):
    if i<popu.shape[0]-1 :
        change=np.append(change,popu[i+1]-popu[i])
print(change)
# Out:
# [ 101984.  181326.  250184. -641579.   80967.   49751.   42542.   20930.
#    -3890.  -26943.]

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
zhfont1 = matplotlib.font_manager.FontProperties(fname="G:\my_lovely_codes\math_model\ZH_ZN\SourceHanSansSC-Regular.otf") 
sns.set_theme(style="darkgrid")
plt.figure(figsize=(10, 6)) 
plt.title("NYC 人口变化", fontproperties=zhfont1, fontsize=20)
plt.xlabel("年份", fontproperties=zhfont1, fontsize=16)
plt.ylabel("人口变化", fontproperties=zhfont1, fontsize=16)
sns.lineplot(y=change,x=np.arange(1, len(change) + 1), color='red')
plt.show()
